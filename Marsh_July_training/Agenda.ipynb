-- %%
Capstone Project



--Spark ( DAG )
--Optimization on Spark 
-- Zorder and liquid cluster
-- Open Sharing (Delta Sharing)
-- Types of Views  (std view, materailised view, dynamic view)
--DAB
--CI/CD
--Free edition 
--Databricks SQL 
--Lakehouse federation
--UC table to Power bi
--Unity Catalog
--GitHub
--CLI
--Pipelines
--Certification 
--mid and post assessment

-- %%
DE


notebooks
sql
pipeline
Dashboard


jobs
