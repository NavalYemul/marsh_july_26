-- %%
Types of Views 
DAB
CI/CD

Spark ( DAG )
Optimization on Spark 
Zorder and liquid
Capsont Project

Open Sharing

--Free edition 
--Databricks SQL 
--Lakehouse federation
--UC table to Power bi
--Unity Catalog
--GitHub
--CLI
--Pipelines
--Certification 
--mid and post assessment
