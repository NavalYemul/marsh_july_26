-- %% [markdown]
-- https://docs.databricks.com/aws/en/database-objects/

-- %% [markdown]
-- ![](/Volumes/dev/naval/raw/object-model-afbb2181ddc2c1c8783a74a5cece58f2.png)

-- %%
%python
print("hello world")

-- %%
select "Welcome to Databricks"

-- %%
select * from samples.bakehouse.sales_customers

-- %%
select * from samples.bakehouse.sales_transactions

-- %% [markdown]
-- ## Data objects

-- %%
create schema if not exists dev.naval;

-- %%
use catalog dev;

-- %%
create schema naval;

-- %%
use catalog dev;
use schema naval;

-- %%
create table if not exists dev.naval.demo (id int, name string)
