-- %%
lakeflow: unified de platform within Databricks
 4 core components


1. Lakeflow connect: (Data ingestion) : external apps, db, dw ( ingest into databricks (catalog)) (Done)

2. lakeflow spark declartive pipeline (Delta Live table) : Transforming ( sql, python) (Done)

3. lakeflow jobs : Orchestation tool, scheduler (Done)
4. lakeflow designer (visual data prep):no code tool ETL (Done)

-- %%
Lakehouse: data warehouse + Data Lake

ACID 


Delta lake : open source storage frame
