# %%
df_finance=spark.read.csv("/Volumes/dev/naval/raw/transactions.csv",header=True,inferSchema=True)

# %%
#df_finance.display()

# %%
df_credit=df_finance.filter("transaction_type='Credit'")

# %%
from pyspark.sql.functions import current_timestamp,col

# %%
df_1=df_finance.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_name"))

# %%
df_1.display()

# %%
# %sql
--create table if not exists dev.naval.transactions_metadata as 
select *, _metadata.file_path, _metadata.file_name , current_timestamp as ingestion_time from read_files("/Volumes/dev/naval/raw/transactions.csv")

# %%
# %sql
--create table if not exists dev.naval.transactions_metadata as 
select *, _metadata.file_path, _metadata.file_name , current_timestamp as ingestion_time from read_files("/Volumes/dev/naval/raw/transactions.csv")

# %%
# %sql
create or replace table dev.naval.transactions_metadata as 
select *, _metadata.file_path, _metadata.file_name , current_timestamp as ingestion_time from read_files("/Volumes/dev/naval/raw/transactions.csv")

# %%
# reader API/ Extraction
df_finance=spark.read.csv("/Volumes/dev/naval/raw/transactions.csv",header=True,inferSchema=True)


# Metada
df1=(
    df_finance.withColumn("ingestion_date",current_timestamp())
    .withColumn("path",col("_metadata.file_name"))
    .withColumn("path",col("_metadata.file_path"))
    )

# %%
#writing
df1.write.mode("overwrite").saveAsTable("dev.naval.transactions_pyspark")

# %%
df_sql=spark.sql('select *, _metadata.file_path, _metadata.file_name , current_timestamp as ingestion_time from read_files("/Volumes/dev/naval/raw/transactions.csv")')

# %%
df_sql.display()

# %%
df_finance=spark.read.csv("/Volumes/dev/naval/raw/transactions.csv",header=True,inferSchema=True)


# Metada
df1=(
    df_finance.withColumn("ingestion_date",current_timestamp())
    .withColumn("path",col("_metadata.file_name"))
    .withColumn("path",col("_metadata.file_path"))
    )

# %%
df1.filter("transaction_type='Credit'").explain()

# %%
df1.filter("transaction_type='Credit'").explain(True)

# %%
df1.filter("transaction_type='Credit'").display()
