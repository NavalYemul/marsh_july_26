# %%
print("hello")

# %%
spark.version

# %%
rdd
df
ds

# %%
Reader api 

    df=spark.read.format("csv").path("")
    df=spark.read.csv("path")
Writer api

transform

# %%
# %sql
--create table if not exists dev.naval.transactions as 
select * from read_files("/Volumes/dev/naval/raw/transactions.csv")

# %%
df=spark.read.table("dev.naval.transactions")

# %%
spark.read.csv("/Volumes/dev/naval/raw/transactions.csv")

# %%
# %sql
select *,current_timestamp()  as ingestion_date from read_files("/Volumes/dev/naval/raw/transactions.csv")

# %%
df=spark.read.csv("/Volumes/dev/naval/raw/transactions.csv",header=True,inferSchema=True)

# %%
df.display()

# %%
df.filter("transaction_type='Credit'")

# %%
Lazy Evaluation: 


Transformations  (Plan)
1. read


Actions (Execute the Plan)
1. show
2. display
3.write
