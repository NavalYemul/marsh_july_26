-- %%
Overview of Data Goverance

-- %%
Data Access Control

-- %%
grant privilege on object object_name to principals
revoke privilegs on object object_name from principals

-- %%
grant use catalog on catalog dev to `account users`

-- %%
grant use catalog on catalog dev to `account users`;
grant use schema on schema dev.naval_silver to `account users`;
grant execute on function dev.naval_silver.classify_amount_tier to `account users`
