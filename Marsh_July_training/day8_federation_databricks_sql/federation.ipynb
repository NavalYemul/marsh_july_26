-- %%
connect is migration (ingestion ): 
Lakehouse federation (Read only)
1. Query Federation 
2. Catalog federation


query 
Azure sql 
Snowflake
redshift
... 




hdfc
icici 
sbi 



g pay/ phone pe:

-- %%
select * from dev.naval.address

-- %%
create table dev.naval.emp_sql as  
select * from azure_sql_dm.dbo.emp

-- %%
select * from azure_sql_dm.saleslt.address
